# %%
from sklearn import linear_model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %matplotlib inline
matplotlib.style.use('ggplot')

# %%
happy = pd.read_csv('happy.csv')
happy 
happy= happy.rename({'Country name':'Country_name'},axis='columns')
# happy_score = happy['Country name','Regional indicator',"Ladder score"]
# happy_score

# %%
smokers = pd.read_csv('smokers.csv')
smokers
smokers = smokers[smokers["TIME"]==2014]
smokers = smokers.reset_index(drop=True)
smokers.head()
smokers = smokers.rename({'Country name':'Country_name'},axis='columns')
smokers= smokers.rename({'Value':'Value_smokers'},axis='columns')
smokers_score = smokers[['Country_name',"Value_smokers"]]
# smokers_score

# %%
suicide = pd.read_csv('suicide.csv',header = None)
# suicide.head()
suicide = suicide.drop(index=[0],axis=0)
# print(suicide.head())
dt2 = suicide.rename(columns=suicide.iloc[0])
dt2

suicide = dt2.drop(dt2.index[0])
suicide = suicide.reset_index(drop = True)
suicide = suicide.rename({'Country':'Country_name'},axis='columns')
suicide = suicide.rename({'2016':'Value_suicide'},axis='columns')
suicide.head()
suicide_score = suicide[['Country_name','Value_suicide']]
# suicide_score

# %%
alchol = pd.read_csv('alchol.csv')
alchol
alchol= alchol.rename({'Country name':'Country_name'},axis='columns')
alchol= alchol.rename({'Value_alchol':'Value_alchol'},axis='columns')
alchol_score = alchol[['Country_name',"Value_alchol"]]
# alchol_score

# %%
depression = pd.read_csv('depression.csv')
depression
depression= depression.rename({'Country name ':'Country_name'},axis='columns')
depression= depression.rename({'depression':'Value_depression'},axis='columns')
depression_score = depression
# depression_score = depression
# depression_score

# %%
timeuse = pd.read_csv('timeuse.csv')
timeuse

timeuse.dtypes
timeuse.keys()
timeuse = timeuse.rename({'Country':'Country_name'},axis='columns')
timeuse
# Out:
#          Country_name  travel to and from work/study   shopping    sleeping  \
# 0           Australia                      25.017373  29.020153  512.355803
# 1             Austria                      29.363549  20.732446  498.291623
# 2             Belgium                      26.357791  28.595906  512.860239
# 3              Canada                      28.790462  24.095448  520.000000
# 4             Denmark                      23.050637  26.030903  488.607524
# 5             Estonia                      29.423589  23.959773  530.015279
# 6             Finland                      20.771330  26.156200  508.261100
# 7              France                      22.930911  22.105101  512.974630
# 8             Germany                      28.380100  32.090467  498.381500
# 9              Greece                      24.650340  16.354267  500.032935
# 10            Hungary                      28.544039  19.211991  505.896698
# 11            Ireland                      22.753420  27.566740  491.254200
# 12             Italy                       21.329231  27.742728  513.320886
# 13              Japan                      43.492961  24.928908  442.020938
# 14  Republic of Korea                      56.875446  13.271596  471.350749
# 15             Latvia                      36.527166  15.851148  512.289761
# 16          Lithuania                      28.833324  17.276902  503.068938
# 17         Luxembourg                      34.830209  23.030769  518.173357
# 18             Mexico                      39.062764  14.179350  498.695400
# 19        Netherlands                      31.028051  28.202491  502.776319
# 20        New Zealand                      23.000000  24.000000  526.000000
# 21            Norway                       29.730990  20.440920  492.123900
# 22             Poland                      26.851995  25.022830  508.940665
# 23           Portugal                      25.174825  15.104895  505.510489
# 24           Slovenia                      24.965326  17.975035  501.303745
# 25              Spain                      21.434830  25.443760  515.661900
# 26             Sweden                      31.002132  23.455743  482.700987
# 27             Turkey                      30.661840  13.955610  514.581700
# 28     United Kingdom                      39.168778  29.412386  508.110579
# 29      United States                      21.684370  22.013280  528.019500
# 30              China                      46.967384  19.986121  541.623872
# 31              India                      32.022697  11.568416  528.141375
# 32       South Africa                      36.102180   9.480088  553.141700
#
#     eating & drinking  participating / attending events     sports  \
# 0           89.061849                          6.004170  19.013204
# 1           78.836406                          9.431552  32.078530
# 2           98.516408                         15.365886  21.016577
# 3           64.819713                          5.605865  20.998791
# 4          119.153410                          7.439385  22.115072
# 5           78.996207                          7.861110  27.474674
# 6           80.645830                          7.714292  37.230850
# 7          132.757108                         14.842221  11.961101
# 8           94.963150                         13.528252  26.435250
# 9          127.534109                          5.086178  27.687648
# 10         101.130000                          5.640701  12.931679
# 11          75.386560                         41.727780  20.020750
# 12         126.974855                          5.823313  38.214086
# 13          93.454218                               NaN  10.222600
# 14         116.942542                          4.449314  27.188580
# 15          88.867321                          4.796301  24.990631
# 16          88.205405                          1.346944  15.962224
# 17         112.222327                         12.441996  33.237082
# 18          77.002550                          7.206197  13.573350
# 19         114.308190                          6.644919  22.399997
# 20          80.000000                          6.000000  17.000000
# 21          79.379770                          8.056627  20.909070
# 22          90.718431                          2.814595  23.244835
# 23         111.776224                         10.573427  12.083916
# 24          85.880721                          4.993065  31.955617
# 25         125.558200                          9.211836  41.877960
# 26          82.535618                          8.820125  34.343945
# 27         117.581700                          2.580510   9.465469
# 28          79.252174                          7.013408  19.362315
# 29          62.747670                          8.225513  17.946540
# 30          99.930604                          1.998612  22.984039
# 31          83.855192                          4.609206   5.498705
# 32          72.385310                          5.107705   5.085051
#
#     visiting or entertaining friends
# 0                          40.006949
# 1                          81.770630
# 2                          50.476242
# 3                          53.476652
# 4                          81.371521
# 5                          37.624863
# 6                          54.645980
# 7                          55.201073
# 8                          60.646950
# 9                          56.327788
# 10                         35.133410
# 11                         48.954450
# 12                         65.357207
# 13                         16.912066
# 14                         42.215920
# 15                         35.084832
# 16                         31.782461
# 17                         32.301265
# 18                         44.155830
# 19                         72.561857
# 20                         69.000000
# 21                         57.015200
# 22                         45.137010
# 23                         43.804196
# 24                         61.914008
# 25                         50.793500
# 26                         52.703188
# 27                         68.120160
# 28                         47.428318
# 29                         43.543680
# 30                         22.984039
# 31                         73.257531
# 32                         82.146140

# %%
from scipy.stats import shapiro 
#정규성 문제 확인 
number  = shapiro(smokers_score["Value_smokers"])
number

# pvalue=0.4825419485569  > 0.05 보다 크므로 정규성에 문제가 없다.
# Out:
# (0.97971510887146, 0.817926824092865)

# %%
# pd.merge(happy,smokers_score,suicide_score)

total_1 = pd.merge(happy,suicide_score)
total_1['Value_suicide'] = pd.to_numeric(total_1['Value_suicide'])
# total_1

# %%
total_2 = pd.merge(happy,alchol_score)
total_2['Value_alchol'] = pd.to_numeric(total_2['Value_alchol'])
# total_2

# %%
total_3 = pd.merge(happy,smokers_score)
total_3['Value_smokers'] = pd.to_numeric(total_3['Value_smokers'])
# total_3

# %%
total_4= pd.merge(happy,depression_score,on="Country_name")
total_4['Value_depression'] = pd.to_numeric(total_4['Value_depression'])

# %%
total_5= pd.merge(suicide_score,depression_score,on="Country_name")
total_5['Value_depression'] = pd.to_numeric(total_5['Value_depression'])
total_5['Value_suicide'] = pd.to_numeric(total_5['Value_suicide'])

# %%
total_6 = pd.merge(happy,timeuse,on='Country_name')
total_6
# Out:
#          Country_name            Regional indicator  Ladder score  \
# 0           Australia         North America and ANZ        7.2228
# 1             Austria                Western Europe        7.2942
# 2             Belgium                Western Europe        6.8635
# 3              Canada         North America and ANZ        7.2321
# 4               China                     East Asia        5.1239
# 5             Denmark                Western Europe        7.6456
# 6             Estonia    Central and Eastern Europe        6.0218
# 7             Finland                Western Europe        7.8087
# 8              France                Western Europe        6.6638
# 9             Germany                Western Europe        7.0758
# 10             Greece                Western Europe        5.5150
# 11            Hungary    Central and Eastern Europe        6.0004
# 12              India                    South Asia        3.5733
# 13            Ireland                Western Europe        7.0937
# 14              Japan                     East Asia        5.8708
# 15             Latvia    Central and Eastern Europe        5.9500
# 16          Lithuania    Central and Eastern Europe        6.2155
# 17         Luxembourg                Western Europe        7.2375
# 18             Mexico   Latin America and Caribbean        6.4650
# 19        Netherlands                Western Europe        7.4489
# 20        New Zealand         North America and ANZ        7.2996
# 21             Poland    Central and Eastern Europe        6.1863
# 22           Portugal                Western Europe        5.9109
# 23           Slovenia    Central and Eastern Europe        6.3634
# 24       South Africa            Sub-Saharan Africa        4.8141
# 25  Republic of Korea                     East Asia        5.8724
# 26              Spain                Western Europe        6.4009
# 27             Sweden                Western Europe        7.3535
# 28             Turkey  Middle East and North Africa        5.1318
# 29     United Kingdom                Western Europe        7.1645
# 30      United States         North America and ANZ        6.9396
#
#     travel to and from work/study   shopping    sleeping  eating & drinking  \
# 0                       25.017373  29.020153  512.355803          89.061849
# 1                       29.363549  20.732446  498.291623          78.836406
# 2                       26.357791  28.595906  512.860239          98.516408
# 3                       28.790462  24.095448  520.000000          64.819713
# 4                       46.967384  19.986121  541.623872          99.930604
# 5                       23.050637  26.030903  488.607524         119.153410
# 6                       29.423589  23.959773  530.015279          78.996207
# 7                       20.771330  26.156200  508.261100          80.645830
# 8                       22.930911  22.105101  512.974630         132.757108
# 9                       28.380100  32.090467  498.381500          94.963150
# 10                      24.650340  16.354267  500.032935         127.534109
# 11                      28.544039  19.211991  505.896698         101.130000
# 12                      32.022697  11.568416  528.141375          83.855192
# 13                      22.753420  27.566740  491.254200          75.386560
# 14                      43.492961  24.928908  442.020938          93.454218
# 15                      36.527166  15.851148  512.289761          88.867321
# 16                      28.833324  17.276902  503.068938          88.205405
# 17                      34.830209  23.030769  518.173357         112.222327
# 18                      39.062764  14.179350  498.695400          77.002550
# 19                      31.028051  28.202491  502.776319         114.308190
# 20                      23.000000  24.000000  526.000000          80.000000
# 21                      26.851995  25.022830  508.940665          90.718431
# 22                      25.174825  15.104895  505.510489         111.776224
# 23                      24.965326  17.975035  501.303745          85.880721
# 24                      36.102180   9.480088  553.141700          72.385310
# 25                      56.875446  13.271596  471.350749         116.942542
# 26                      21.434830  25.443760  515.661900         125.558200
# 27                      31.002132  23.455743  482.700987          82.535618
# 28                      30.661840  13.955610  514.581700         117.581700
# 29                      39.168778  29.412386  508.110579          79.252174
# 30                      21.684370  22.013280  528.019500          62.747670
#
#     participating / attending events     sports  \
# 0                           6.004170  19.013204
# 1                           9.431552  32.078530
# 2                          15.365886  21.016577
# 3                           5.605865  20.998791
# 4                           1.998612  22.984039
# 5                           7.439385  22.115072
# 6                           7.861110  27.474674
# 7                           7.714292  37.230850
# 8                          14.842221  11.961101
# 9                          13.528252  26.435250
# 10                          5.086178  27.687648
# 11                          5.640701  12.931679
# 12                          4.609206   5.498705
# 13                         41.727780  20.020750
# 14                               NaN  10.222600
# 15                          4.796301  24.990631
# 16                          1.346944  15.962224
# 17                         12.441996  33.237082
# 18                          7.206197  13.573350
# 19                          6.644919  22.399997
# 20                          6.000000  17.000000
# 21                          2.814595  23.244835
# 22                         10.573427  12.083916
# 23                          4.993065  31.955617
# 24                          5.107705   5.085051
# 25                          4.449314  27.188580
# 26                          9.211836  41.877960
# 27                          8.820125  34.343945
# 28                          2.580510   9.465469
# 29                          7.013408  19.362315
# 30                          8.225513  17.946540
#
#     visiting or entertaining friends
# 0                          40.006949
# 1                          81.770630
# 2                          50.476242
# 3                          53.476652
# 4                          22.984039
# 5                          81.371521
# 6                          37.624863
# 7                          54.645980
# 8                          55.201073
# 9                          60.646950
# 10                         56.327788
# 11                         35.133410
# 12                         73.257531
# 13                         48.954450
# 14                         16.912066
# 15                         35.084832
# 16                         31.782461
# 17                         32.301265
# 18                         44.155830
# 19                         72.561857
# 20                         69.000000
# 21                         45.137010
# 22                         43.804196
# 23                         61.914008
# 24                         82.146140
# 25                         42.215920
# 26                         50.793500
# 27                         52.703188
# 28                         68.120160
# 29                         47.428318
# 30                         43.543680

# %%
total_score = pd.merge(happy,suicide_score,on="Country_name",how='left')
total_score = pd.merge(total_score,alchol_score,on="Country_name",how='left')
total_score = pd.merge(total_score,smokers_score,on="Country_name",how='left')
total_score = pd.merge(total_score,depression_score,on="Country_name",how='left')

total_score['Value_suicide'] = pd.to_numeric(total_score['Value_suicide'])

total_score = total_score.fillna(0)
total_score
# Out:
#                  Country_name                  Regional indicator  \
# 0                 Afghanistan                          South Asia
# 1                     Albania          Central and Eastern Europe
# 2                     Algeria        Middle East and North Africa
# 3                   Argentina         Latin America and Caribbean
# 4                     Armenia  Commonwealth of Independent States
# 5                   Australia               North America and ANZ
# 6                     Austria                      Western Europe
# 7                  Azerbaijan  Commonwealth of Independent States
# 8                     Bahrain        Middle East and North Africa
# 9                  Bangladesh                          South Asia
# 10                    Belarus  Commonwealth of Independent States
# 11                    Belgium                      Western Europe
# 12                      Benin                  Sub-Saharan Africa
# 13                    Bolivia         Latin America and Caribbean
# 14     Bosnia and Herzegovina          Central and Eastern Europe
# 15                   Botswana                  Sub-Saharan Africa
# 16                     Brazil         Latin America and Caribbean
# 17                   Bulgaria          Central and Eastern Europe
# 18               Burkina Faso                  Sub-Saharan Africa
# 19                    Burundi                  Sub-Saharan Africa
# 20                   Cambodia                      Southeast Asia
# 21                   Cameroon                  Sub-Saharan Africa
# 22                     Canada               North America and ANZ
# 23   Central African Republic                  Sub-Saharan Africa
# 24                       Chad                  Sub-Saharan Africa
# 25                      Chile         Latin America and Caribbean
# 26                      China                           East Asia
# 27                   Colombia         Latin America and Caribbean
# 28                    Comoros                  Sub-Saharan Africa
# 29        Congo (Brazzaville)                  Sub-Saharan Africa
# ..                        ...                                 ...
# 123                  Slovenia          Central and Eastern Europe
# 124              South Africa                  Sub-Saharan Africa
# 125         Republic of Korea                           East Asia
# 126               South Sudan                  Sub-Saharan Africa
# 127                     Spain                      Western Europe
# 128                 Sri Lanka                          South Asia
# 129                 Swaziland                  Sub-Saharan Africa
# 130                    Sweden                      Western Europe
# 131               Switzerland                      Western Europe
# 132  Taiwan Province of China                           East Asia
# 133                Tajikistan  Commonwealth of Independent States
# 134                  Tanzania                  Sub-Saharan Africa
# 135                  Thailand                      Southeast Asia
# 136                      Togo                  Sub-Saharan Africa
# 137       Trinidad and Tobago         Latin America and Caribbean
# 138                   Tunisia        Middle East and North Africa
# 139                    Turkey        Middle East and North Africa
# 140              Turkmenistan  Commonwealth of Independent States
# 141                    Uganda                  Sub-Saharan Africa
# 142                   Ukraine  Commonwealth of Independent States
# 143      United Arab Emirates        Middle East and North Africa
# 144            United Kingdom                      Western Europe
# 145             United States               North America and ANZ
# 146                   Uruguay         Latin America and Caribbean
# 147                Uzbekistan  Commonwealth of Independent States
# 148                 Venezuela         Latin America and Caribbean
# 149                   Vietnam                      Southeast Asia
# 150                     Yemen        Middle East and North Africa
# 151                    Zambia                  Sub-Saharan Africa
# 152                  Zimbabwe                  Sub-Saharan Africa
#
#      Ladder score  Value_suicide  Value_alchol  Value_smokers  \
# 0          2.5669            6.4           0.0            0.0
# 1          4.8827            5.6           0.0            0.0
# 2          5.0051            3.3           0.0            0.0
# 3          5.9747            9.1           0.0            0.0
# 4          4.6768            5.7           0.0            0.0
# 5          7.2228           11.7           0.0            0.0
# 6          7.2942           11.4          12.2           24.3
# 7          5.1648            2.6           0.0            0.0
# 8          6.2273            5.7           0.0            0.0
# 9          4.8328            6.1           0.0            0.0
# 10         5.5399           21.4           0.0            0.0
# 11         6.8635           15.7           9.4            0.0
# 12         5.2160           15.7           0.0            0.0
# 13         5.7475            0.0           0.0            0.0
# 14         5.6741            6.4           0.0            0.0
# 15         3.4789           11.5           0.0            0.0
# 16         6.3756            6.1           6.2            8.7
# 17         5.1015            7.9           0.0            0.0
# 18         4.7687           14.8           0.0            0.0
# 19         3.7753           15.0           0.0            0.0
# 20         4.8484            5.9           0.0            0.0
# 21         5.0849           19.5           0.0            0.0
# 22         7.2321           10.4           8.2           14.0
# 23         3.4759           11.6           0.0            0.0
# 24         4.4227           15.5           0.0            0.0
# 25         6.2285            9.7           0.0            0.0
# 26         5.1239            8.0           5.6            0.0
# 27         6.1634            7.0           4.3            0.0
# 28         4.2886           11.1           0.0            0.0
# 29         5.1944            0.0           0.0            0.0
# ..            ...            ...           ...            ...
# 123        6.3634           13.3          10.0           18.9
# 124        4.8141           12.8           7.3            0.0
# 125        5.8724           20.2           8.5           20.0
# 126        2.8166            6.1           0.0            0.0
# 127        6.4009            6.1          10.4           23.0
# 128        4.3270           14.2           0.0            0.0
# 129        4.3081            0.0           0.0            0.0
# 130        7.3535           11.7           7.2           11.9
# 131        7.5599           11.3           9.1            0.0
# 132        6.4554            0.0           0.0            0.0
# 133        5.5557            3.3           0.0            0.0
# 134        3.4762            0.0           0.0            0.0
# 135        5.9988           12.9           0.0            0.0
# 136        4.1872           16.6           0.0            0.0
# 137        6.1919           12.9           0.0            0.0
# 138        4.3922            3.2           0.0            0.0
# 139        5.1318            7.2           1.4           27.3
# 140        5.1191            7.2           0.0            0.0
# 141        4.4320           20.0           0.0            0.0
# 142        4.5607           18.5           0.0            0.0
# 143        6.7908            2.7           0.0            0.0
# 144        7.1645            0.0           9.8           19.0
# 145        6.9396            0.0           0.0           12.9
# 146        6.4401           16.5           0.0            0.0
# 147        6.2576            7.4           0.0            0.0
# 148        5.0532            0.0           0.0            0.0
# 149        5.3535            0.0           0.0            0.0
# 150        3.5274            9.8           0.0            0.0
# 151        3.7594           11.3           0.0            0.0
# 152        3.2992           19.1           0.0            0.0
#
#      Value_depression
# 0                9.19
# 1                5.11
# 2                4.12
# 3               10.61
# 4                8.26
# 5               11.05
# 6               11.20
# 7                4.07
# 8                4.23
# 9                6.03
# 10              19.03
# 11              14.28
# 12              11.14
# 13               6.41
# 14               6.85
# 15              10.01
# 16               6.09
# 17               9.48
# 18              13.21
# 19              12.62
# 20               4.54
# 21              14.03
# 22              10.91
# 23              16.93
# 24              11.02
# 25              10.14
# 26               7.21
# 27               5.53
# 28               8.32
# 29               0.00
# ..                ...
# 123             14.38
# 124             11.15
# 125              0.00
# 126             12.00
# 127              5.51
# 128             19.80
# 129             22.32
# 130             11.08
# 131              9.32
# 132              0.00
# 133              5.75
# 134              8.82
# 135             10.44
# 136             12.26
# 137             10.12
# 138              3.11
# 139              3.31
# 140              8.68
# 141             11.54
# 142             25.62
# 143              5.07
# 144              7.36
# 145             12.84
# 146             16.82
# 147              9.39
# 148              8.68
# 149              7.42
# 150              6.01
# 151             13.06
# 152             26.39
#
# [153 rows x 7 columns]

# %%
# from scipy.stats import shapiro 
# shapiro(total_1)
sns.pairplot(total_1)
plt.show()

# %%
sns.pairplot(total_2)
plt.show()

# %%
sns.pairplot(total_3)
plt.show()

# %%
sns.pairplot(total_4)
plt.show()

# %%
sns.pairplot(total_5)
plt.show()

# %%
sns.pairplot(total_6)
plt.show()
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\numpy\lib\histograms.py:746: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\numpy\lib\histograms.py:747: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.distplot(total_1.Value_suicide)
plt.title('A group Histogram')
# plt.show()
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'A group Histogram')

# %%
sns.distplot(total_2.Value_alchol)
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(total_3.Value_smokers)
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(total_4.Value_depression)
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(total_1['Ladder score'])
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(total_6['travel to and from work/study'])
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(total_6['shopping'])
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(total_6['sleeping'])
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(total_6['eating & drinking'])
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
total_6.keys()
# Out:
# Index(['Country_name', 'Regional indicator', 'Ladder score',
#        'travel to and from work/study', 'shopping', 'sleeping',
#        'eating & drinking', 'participating / attending events', 'sports',
#        'visiting or entertaining friends'],
#       dtype='object')

# %%
#자살률과 행복도의 관계
sns.lmplot(x="Ladder score", y="Value_suicide", data=total_1 , line_kws={'color':"red"})
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#행복도와 흡연과의 관계
sns.lmplot(x="Ladder score", y="Value_smokers", data=total_3, line_kws={'color':"red"})
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# 행복도과 음주소비와의 관계
sns.lmplot(x="Ladder score", y="Value_alchol", data=total_2 , line_kws={'color':"red"})
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#행복도와 우울증의 상관관계 
sns.lmplot(x="Ladder score", y="Value_depression", data=total_4 , line_kws={'color':"red"})
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lmplot(x="Value_depression", y="Value_suicide", data=total_5 , line_kws={'color':"red"})
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
total_5.corr()
# Out:
#                   Value_suicide  Value_depression
# Value_suicide          1.000000          0.786807
# Value_depression       0.786807          1.000000

# %%
# 술먹으면 행복하고 담배하면 불행하고 , 사실 행복과 자살은 크게 관련이 없지만 음의 관계는 약간있을 수 있다.
# ?????????????????

# %%
# 대륙별 차이?를 확인해봐라 
total_score['Value_depression'].head()
# Out:
# 0     9.19
# 1     5.11
# 2     4.12
# 3    10.61
# 4     8.26
# Name: Value_depression, dtype: float64

# %%
sns.heatmap(total_score.corr(), annot=True, cmap="Reds")
plt.show()

# %%
sns.heatmap(total_6.corr(), annot=True, cmap="Reds")
plt.show()

# %%
total_score.cov()
# Out:
#                   Ladder score  Value_suicide  Value_alchol  Value_smokers  \
# Ladder score          1.237145      -0.504728      1.136598      -2.233982
# Value_suicide        -0.504728      25.972033      6.394476       3.216880
# Value_alchol          1.136598       6.394476      9.404246       5.277222
# Value_smokers        -2.233982       3.216880      5.277222      31.117989
# Value_depression     -0.907105      21.852426      6.826049       2.297429
#
#                   Value_depression
# Ladder score             -0.907105
# Value_suicide            21.852426
# Value_alchol              6.826049
# Value_smokers             2.297429
# Value_depression         26.991164

# %%
# Out:
# Index(['Country_name', 'travel to and from work/study', 'shopping', 'sleeping',
#        'eating & drinking', 'participating / attending events', 'sports',
#        'visiting or entertaining friends'],
#       dtype='object')

# %%
total_6.corr()
# Out:
#                                   Ladder score  travel to and from work/study  \
# Ladder score                          1.000000                      -0.373837
# travel to and from work/study        -0.373837                       1.000000
# shopping                              0.743190                      -0.348938
# sleeping                             -0.261687                      -0.219024
# eating & drinking                    -0.116794                       0.017845
# participating / attending events      0.325630                      -0.300477
# sports                                0.499810                      -0.145023
# visiting or entertaining friends      0.068342                      -0.356222
#
#                                   shopping  sleeping  eating & drinking  \
# Ladder score                      0.743190 -0.261687          -0.116794
# travel to and from work/study    -0.348938 -0.219024           0.017845
# shopping                          1.000000 -0.200382          -0.048143
# sleeping                         -0.200382  1.000000          -0.216109
# eating & drinking                -0.048143 -0.216109           1.000000
# participating / attending events  0.386427 -0.239228          -0.065678
# sports                            0.393298 -0.140034           0.112951
# visiting or entertaining friends -0.091313  0.213359           0.007670
#
#                                   participating / attending events    sports  \
# Ladder score                                              0.325630  0.499810
# travel to and from work/study                            -0.300477 -0.145023
# shopping                                                  0.386427  0.393298
# sleeping                                                 -0.239228 -0.140034
# eating & drinking                                        -0.065678  0.112951
# participating / attending events                          1.000000  0.065191
# sports                                                    0.065191  1.000000
# visiting or entertaining friends                          0.006203 -0.044574
#
#                                   visiting or entertaining friends
# Ladder score                                              0.068342
# travel to and from work/study                            -0.356222
# shopping                                                 -0.091313
# sleeping                                                  0.213359
# eating & drinking                                         0.007670
# participating / attending events                          0.006203
# sports                                                   -0.044574
# visiting or entertaining friends                          1.000000

# %%
sns.lmplot(x="sleeping", y="Ladder score", data=total_6 , line_kws={'color':"red"})
sns.lmplot(x="travel to and from work/study", y="Ladder score", data=total_6 , line_kws={'color':"red"})
sns.lmplot(x="shopping", y="Ladder score", data=total_6 , line_kws={'color':"red"})
sns.lmplot(x="eating & drinking", y="Ladder score", data=total_6 , line_kws={'color':"red"})
sns.lmplot(x="participating / attending events", y="Ladder score", data=total_6 , line_kws={'color':"red"})
sns.lmplot(x="sports", y="Ladder score", data=total_6 , line_kws={'color':"red"})
sns.lmplot(x="visiting or entertaining friends", y="Ladder score", data=total_6 , line_kws={'color':"red"})
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
timeuse.head()
# Out:
#   Country_name  travel to and from work/study   shopping    sleeping  \
# 0    Australia                      25.017373  29.020153  512.355803
# 1      Austria                      29.363549  20.732446  498.291623
# 2      Belgium                      26.357791  28.595906  512.860239
# 3       Canada                      28.790462  24.095448  520.000000
# 4      Denmark                      23.050637  26.030903  488.607524
#
#    eating & drinking  participating / attending events     sports  \
# 0          89.061849                          6.004170  19.013204
# 1          78.836406                          9.431552  32.078530
# 2          98.516408                         15.365886  21.016577
# 3          64.819713                          5.605865  20.998791
# 4         119.153410                          7.439385  22.115072
#
#    visiting or entertaining friends
# 0                         40.006949
# 1                         81.770630
# 2                         50.476242
# 3                         53.476652
# 4                         81.371521

# %%
timeuse.corr()
# Out:
#                                   travel to and from work/study  shopping  \
# travel to and from work/study                          1.000000 -0.371517
# shopping                                              -0.371517  1.000000
# sleeping                                              -0.220999 -0.180181
# eating & drinking                                     -0.038648  0.014907
# participating / attending events                      -0.282321  0.366820
# sports                                                -0.194949  0.425200
# visiting or entertaining friends                      -0.374062 -0.063461
# mltisleeping                                          -0.220999 -0.180181
#
#                                   sleeping  eating & drinking  \
# travel to and from work/study    -0.220999          -0.038648
# shopping                         -0.180181           0.014907
# sleeping                          1.000000          -0.168695
# eating & drinking                -0.168695           1.000000
# participating / attending events -0.235616          -0.079583
# sports                           -0.113851           0.194999
# visiting or entertaining friends  0.207957           0.042415
# mltisleeping                      1.000000          -0.168695
#
#                                   participating / attending events    sports  \
# travel to and from work/study                            -0.282321 -0.194949
# shopping                                                  0.366820  0.425200
# sleeping                                                 -0.235616 -0.113851
# eating & drinking                                        -0.079583  0.194999
# participating / attending events                          1.000000  0.042456
# sports                                                    0.042456  1.000000
# visiting or entertaining friends                         -0.003280  0.003026
# mltisleeping                                             -0.235616 -0.113851
#
#                                   visiting or entertaining friends  \
# travel to and from work/study                            -0.374062
# shopping                                                 -0.063461
# sleeping                                                  0.207957
# eating & drinking                                         0.042415
# participating / attending events                         -0.003280
# sports                                                    0.003026
# visiting or entertaining friends                          1.000000
# mltisleeping                                              0.207957
#
#                                   mltisleeping
# travel to and from work/study        -0.220999
# shopping                             -0.180181
# sleeping                              1.000000
# eating & drinking                    -0.168695
# participating / attending events     -0.235616
# sports                               -0.113851
# visiting or entertaining friends      0.207957
# mltisleeping                          1.000000

# %%
total_6.corr()
# Out:
#                                   Ladder score  travel to and from work/study  \
# Ladder score                          1.000000                      -0.373837
# travel to and from work/study        -0.373837                       1.000000
# shopping                              0.743190                      -0.348938
# sleeping                             -0.261687                      -0.219024
# eating & drinking                    -0.116794                       0.017845
# participating / attending events      0.325630                      -0.300477
# sports                                0.499810                      -0.145023
# visiting or entertaining friends      0.068342                      -0.356222
#
#                                   shopping  sleeping  eating & drinking  \
# Ladder score                      0.743190 -0.261687          -0.116794
# travel to and from work/study    -0.348938 -0.219024           0.017845
# shopping                          1.000000 -0.200382          -0.048143
# sleeping                         -0.200382  1.000000          -0.216109
# eating & drinking                -0.048143 -0.216109           1.000000
# participating / attending events  0.386427 -0.239228          -0.065678
# sports                            0.393298 -0.140034           0.112951
# visiting or entertaining friends -0.091313  0.213359           0.007670
#
#                                   participating / attending events    sports  \
# Ladder score                                              0.325630  0.499810
# travel to and from work/study                            -0.300477 -0.145023
# shopping                                                  0.386427  0.393298
# sleeping                                                 -0.239228 -0.140034
# eating & drinking                                        -0.065678  0.112951
# participating / attending events                          1.000000  0.065191
# sports                                                    0.065191  1.000000
# visiting or entertaining friends                          0.006203 -0.044574
#
#                                   visiting or entertaining friends
# Ladder score                                              0.068342
# travel to and from work/study                            -0.356222
# shopping                                                 -0.091313
# sleeping                                                  0.213359
# eating & drinking                                         0.007670
# participating / attending events                          0.006203
# sports                                                   -0.044574
# visiting or entertaining friends                          1.000000

# %%
import scipy.stats as stats
stats.skew(total_6['travel to and from work/study'])  #첨도 확인
# Out:
# 1.4029242415124157

# %%
sns.distplot(total_6['travel to and from work/study'])
# Out:
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from statsmodels.formula.api import ols 
res = ols('sleeping ~ sports+shopping',total_6 ).fit()
res.summary()                    #선형 회귀 분석
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               sleeping   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                 -0.024
# Method:                 Least Squares   F-statistic:                    0.6534
# Date:                Tue, 10 Nov 2020   Prob (F-statistic):              0.528
# Time:                        18:15:59   Log-Likelihood:                -136.46
# No. Observations:                  31   AIC:                             278.9
# Df Residuals:                      28   BIC:                             283.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    524.2910     14.950     35.070      0.000     493.668     554.914
# sports        -0.1621      0.450     -0.360      0.721      -1.083       0.759
# shopping      -0.6026      0.704     -0.856      0.399      -2.045       0.840
# ==============================================================================
# Omnibus:                       11.983   Durbin-Watson:                   2.359
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.782
# Skew:                          -1.053   Prob(JB):                      0.00168
# Kurtosis:                       5.337   Cond. No.                         127.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
